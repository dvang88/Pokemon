# %%
import matplotlib as mpl
import matplotlib.pyplot as plt 
# %matplotlib inline
import seaborn as sns
import pandas as pd
import statsmodels.api as sm
sns.set_style("darkgrid")
mpl.rcParams['figure.figsize'] = (20,5)

# %%
pokemon = pd.read_csv('pokemon_data.csv', encoding='latin-1')
pokemon.head()
# Out:
#          Name          Name2 Primary Type Secondary type  Attack  Defense  HP  \
# 0   Bulbasaur            NaN        GRASS         POISON      49       49  45
# 1     Ivysaur            NaN        GRASS         POISON      62       63  60
# 2    Venusaur            NaN        GRASS         POISON      82       83  80
# 3    Venusaur  Mega Venusaur        GRASS         POISON     100      123  80
# 4  Charmander            NaN         FIRE            NaN      52       43  39
#
#    Sp.Attack  Sp.Defense  Speed  Total
# 0         65          65     45    318
# 1         80          80     60    405
# 2        100         100     80    525
# 3        122         120     80    625
# 4         60          50     65    309

# %%
pokemon.describe()
# Out:
#             Attack      Defense           HP    Sp.Attack   Sp.Defense  \
# count  1045.000000  1045.000000  1045.000000  1045.000000  1045.000000
# mean     80.466986    74.661244    70.067943    73.022010    72.288995
# std      32.413665    31.237903    26.671411    32.724797    28.074148
# min       5.000000     5.000000     1.000000    10.000000    20.000000
# 25%      55.000000    50.000000    50.000000    50.000000    50.000000
# 50%      77.000000    70.000000    68.000000    65.000000    70.000000
# 75%     100.000000    90.000000    82.000000    95.000000    90.000000
# max     190.000000   250.000000   255.000000   194.000000   250.000000
#
#              Speed        Total
# count  1045.000000  1045.000000
# mean     68.807656   439.314833
# std      30.210094   121.970701
# min       5.000000   175.000000
# 25%      45.000000   330.000000
# 50%      65.000000   458.000000
# 75%      90.000000   515.000000
# max     200.000000  1125.000000

# %%
pokemon.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1045 entries, 0 to 1044
# Data columns (total 11 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Name            1045 non-null   object
#  1   Name2           175 non-null    object
#  2   Primary Type    1045 non-null   object
#  3   Secondary type  553 non-null    object
#  4   Attack          1045 non-null   int64
#  5   Defense         1045 non-null   int64
#  6   HP              1045 non-null   int64
#  7   Sp.Attack       1045 non-null   int64
#  8   Sp.Defense      1045 non-null   int64
#  9   Speed           1045 non-null   int64
#  10  Total           1045 non-null   int64
# dtypes: int64(7), object(4)
# memory usage: 89.9+ KB

# %%
max_spattack = pokemon.loc[pokemon['Sp.Attack'].idxmax()]
print(max_spattack)
# Out:
# Name                     Mewtwo
# Name2             Mega Mewtwo Y
# Primary Type            PSYCHIC
# Secondary type              NaN
# Attack                      150
# Defense                      70
# HP                          106
# Sp.Attack                   194
# Sp.Defense                  120
# Speed                       140
# Total                       780
# Name: 195, dtype: object

# %%
max_spdefense = pokemon.loc[pokemon['Sp.Defense'].idxmax()]
print(max_spdefense)
# Out:
# Name              Eternatus
# Name2             Eternamax
# Primary Type         POISON
# Secondary type       DRAGON
# Attack                  115
# Defense                 250
# HP                      255
# Sp.Attack               125
# Sp.Defense              250
# Speed                   130
# Total                  1125
# Name: 1033, dtype: object

# %%
max_HP = pokemon.loc[pokemon['HP'].idxmax()]
print(max_HP)
# Out:
# Name              Blissey
# Name2                 NaN
# Primary Type       NORMAL
# Secondary type        NaN
# Attack                 10
# Defense                10
# HP                    255
# Sp.Attack              75
# Sp.Defense            135
# Speed                  55
# Total                 540
# Name: 294, dtype: object

# %%
max_attack = pokemon.loc[pokemon['Attack'].idxmax()]
print(max_attack)
# Out:
# Name                     Mewtwo
# Name2             Mega Mewtwo X
# Primary Type            PSYCHIC
# Secondary type         FIGHTING
# Attack                      190
# Defense                     100
# HP                          106
# Sp.Attack                   154
# Sp.Defense                  100
# Speed                       130
# Total                       780
# Name: 194, dtype: object

# %%
max_defense = pokemon.loc[pokemon['Defense'].idxmax()]
print(max_defense)
# Out:
# Name              Eternatus
# Name2             Eternamax
# Primary Type         POISON
# Secondary type       DRAGON
# Attack                  115
# Defense                 250
# HP                      255
# Sp.Attack               125
# Sp.Defense              250
# Speed                   130
# Total                  1125
# Name: 1033, dtype: object

# %%
max_speed = pokemon.loc[pokemon['Speed'].idxmax()]
print(max_speed)
# Out:
# Name              Regieleki
# Name2                   NaN
# Primary Type       ELECTRIC
# Secondary type          NaN
# Attack                  100
# Defense                  50
# HP                       80
# Sp.Attack               100
# Sp.Defense               50
# Speed                   200
# Total                   580
# Name: 1038, dtype: object

# %%
max_total = pokemon.loc[pokemon['Total'].idxmax()]
print(max_total)
# Out:
# Name              Eternatus
# Name2             Eternamax
# Primary Type         POISON
# Secondary type       DRAGON
# Attack                  115
# Defense                 250
# HP                      255
# Sp.Attack               125
# Sp.Defense              250
# Speed                   130
# Total                  1125
# Name: 1033, dtype: object

# %%
ListOfVariables = ['Sp.Attack', 'Sp.Defense', 'HP', 'Attack', 'Defense', 'Speed', 'Total']
print(ListOfVariables)
for status in ListOfVariables:
    first_axis = pokemon[status].plot() 
    second_axis = first_axis.twinx() 
    second_axis.plot(pokemon['Total'], color='red')
    plt.title(status)
    plt.show()
# Out:
# ['Sp.Attack', 'Sp.Defense', 'HP', 'Attack', 'Defense', 'Speed', 'Total']

# %%
pokemon.sort_values('Sp.Attack', ascending = False)[:10]
# Out:
#           Name           Name2 Primary Type Secondary type  Attack  Defense  \
# 195     Mewtwo   Mega Mewtwo Y      PSYCHIC            NaN     150       70
# 467     Deoxys    Attack Forme      PSYCHIC            NaN     180       20
# 464   Rayquaza   Mega Rayquaza       DRAGON         FLYING     180      100
# 460     Kyogre   Primal Kyogre        WATER            NaN     150       90
# 84    Alakazam   Mega Alakazam      PSYCHIC            NaN      50       65
# 929  Xurkitree             NaN     ELECTRIC            NaN      89       71
# 125     Gengar     Mega Gengar        GHOST         POISON      65       80
# 845      Hoopa   Hoopa Unbound      PSYCHIC           DARK     160       60
# 756     Kyurem    White Kyurem       DRAGON            ICE     120       90
# 936   Necrozma  Ultra Necrozma      PSYCHIC         DRAGON     167       97
#
#       HP  Sp.Attack  Sp.Defense  Speed  Total
# 195  106        194         120    140    780
# ...

# %%
pokemon.sort_values('Sp.Defense', ascending = False)[:10]
# Out:
#            Name          Name2 Primary Type Secondary type  Attack  Defense  \
# 1033  Eternatus      Eternamax       POISON         DRAGON     115      250
# 262     Shuckle            NaN          BUG           ROCK      10      230
# 453      Regice            NaN          ICE            NaN      50      100
# 468      Deoxys  Defense Forme      PSYCHIC            NaN      70      160
# 460      Kyogre  Primal Kyogre        WATER            NaN     150       90
# 302       Lugia            NaN      PSYCHIC         FLYING      90      130
# 784     Florges            NaN        FAIRY            NaN      65       68
# 303       Ho-oh            NaN         FIRE         FLYING     130       90
# 842     Diancie            NaN         ROCK          FAIRY     100      150
# 821      Goodra            NaN       DRAGON            NaN     100       70
#
#        HP  Sp.Attack  Sp.Defense  Speed  Total
# 1033  255        125         250    130   1125
# ...

# %%
pokemon.sort_values('HP', ascending = False)[:10]
# Out:
#            Name           Name2 Primary Type Secondary type  Attack  Defense  \
# 294     Blissey             NaN       NORMAL            NaN      10       10
# 1033  Eternatus       Eternamax       POISON         DRAGON     115      250
# 147     Chansey             NaN       NORMAL            NaN       5        5
# 932    Guzzlord             NaN         DARK         DRAGON     101       53
# 841     Zygarde  Complete Forme       DRAGON         GROUND     100      121
# 1039  Regidrago             NaN       DRAGON            NaN     100       50
# 249   Wobbuffet             NaN      PSYCHIC            NaN      33       58
# 386     Wailord             NaN        WATER            NaN      90       45
# 698   Alomomola             NaN        WATER            NaN      75       80
# 183     Snorlax             NaN       NORMAL            NaN     110       65
#
#        HP  Sp.Attack  Sp.Defense  Speed  Total
# 294   255         75         135     55    540
# ...

# %%
pokemon.sort_values('Attack', ascending = False)[:10]
# Out:
#            Name           Name2 Primary Type Secondary type  Attack  Defense  \
# 194      Mewtwo   Mega Mewtwo X      PSYCHIC       FIGHTING     190      100
# 264   Heracross  Mega Heracross          BUG       FIGHTING     185      115
# 931     Kartana             NaN        GRASS          STEEL     181      131
# 462     Groudon  Primal Groudon       GROUND           FIRE     180      160
# 464    Rayquaza   Mega Rayquaza       DRAGON         FLYING     180      100
# 467      Deoxys    Attack Forme      PSYCHIC            NaN     180       20
# 532    Garchomp   Mega Garchomp       DRAGON         GROUND     170      115
# 755      Kyurem    Black Kyurem       DRAGON            ICE     170      100
# 1028     Zacian   Crowned Sword        FAIRY          STEEL     170      115
# 936    Necrozma  Ultra Necrozma      PSYCHIC         DRAGON     167       97
#
#        HP  Sp.Attack  Sp.Defense  Speed  Total
# 194   106        154         100    130    780
# ...

# %%
pokemon.sort_values('Defense', ascending = False)[:10]
# Out:
#            Name         Name2 Primary Type Secondary type  Attack  Defense  \
# 1033  Eternatus     Eternamax       POISON         DRAGON     115      250
# 256     Steelix  Mega Steelix        STEEL         GROUND     125      230
# 262     Shuckle           NaN          BUG           ROCK      10      230
# 368      Aggron   Mega Aggron        STEEL            NaN     140      230
# 941   Stakataka           NaN         ROCK          STEEL     131      211
# 452    Regirock           NaN         ROCK            NaN     100      200
# 255     Steelix           NaN        STEEL         GROUND      85      200
# 834     Avalugg           NaN          ICE            NaN     117      184
# 367      Aggron           NaN        STEEL           ROCK     110      180
# 106     Slowbro  Mega Slowbro        WATER        PSYCHIC      75      180
#
#        HP  Sp.Attack  Sp.Defense  Speed  Total
# 1033  255        125         250    130   1125
# 256    75         55          95     30    610
# ...

# %%
pokemon.sort_values('Speed', ascending = False)[:10]
# Out:
#             Name            Name2 Primary Type Secondary type  Attack  \
# 1038   Regieleki              NaN     ELECTRIC            NaN     100
# 469       Deoxys      Speed Forme      PSYCHIC            NaN      95
# 350      Ninjask              NaN          BUG         FLYING      90
# 928    Pheromosa              NaN          BUG       FIGHTING     137
# 1044     Calyrex     Shadow Rider      PSYCHIC          GHOST      85
# 84      Alakazam    Mega Alakazam      PSYCHIC            NaN      50
# 466       Deoxys     Normal Forme      PSYCHIC            NaN     150
# 467       Deoxys     Attack Forme      PSYCHIC            NaN     180
# 132    Electrode              NaN     ELECTRIC            NaN      50
# 182   Aerodactyl  Mega Aerodactyl         ROCK         FLYING     135
#
#       Defense   HP  Sp.Attack  Sp.Defense  Speed  Total
# 1038       50   80        100          50    200    580
# 469        90   50         95          90    180    600
# ...

# %%
pokemon.sort_values('Total', ascending = False)[:10]
# Out:
#            Name           Name2 Primary Type Secondary type  Attack  Defense  \
# 1033  Eternatus       Eternamax       POISON         DRAGON     115      250
# 464    Rayquaza   Mega Rayquaza       DRAGON         FLYING     180      100
# 195      Mewtwo   Mega Mewtwo Y      PSYCHIC            NaN     150       70
# 194      Mewtwo   Mega Mewtwo X      PSYCHIC       FIGHTING     190      100
# 460      Kyogre   Primal Kyogre        WATER            NaN     150       90
# 462     Groudon  Primal Groudon       GROUND           FIRE     180      160
# 936    Necrozma  Ultra Necrozma      PSYCHIC         DRAGON     167       97
# 1030  Zamazenta  Crowned Shield     FIGHTING          STEEL     130      145
# 1028     Zacian   Crowned Sword        FAIRY          STEEL     170      115
# 590      Arceus             NaN       NORMAL            NaN     120      120
#
#        HP  Sp.Attack  Sp.Defense  Speed  Total
# 1033  255        125         250    130   1125
# ...

# %%
pokemon.sort_values('Sp.Attack', ascending = False)[:10]['Primary Type'].value_counts()
# Out:
# PSYCHIC     5
# DRAGON      2
# WATER       1
# ELECTRIC    1
# GHOST       1
# Name: Primary Type, dtype: int64

# %%
pokemon.sort_values('Sp.Defense', ascending = False)[:10]['Primary Type'].value_counts()
# Out:
# PSYCHIC    2
# POISON     1
# BUG        1
# ICE        1
# WATER      1
# FAIRY      1
# FIRE       1
# ROCK       1
# DRAGON     1
# Name: Primary Type, dtype: int64

# %%
pokemon.sort_values('HP', ascending = False)[:10]['Primary Type'].value_counts()
# Out:
# NORMAL     3
# DRAGON     2
# WATER      2
# POISON     1
# DARK       1
# PSYCHIC    1
# Name: Primary Type, dtype: int64

# %%
pokemon.sort_values('Attack', ascending = False)[:10]['Primary Type'].value_counts()
# Out:
# PSYCHIC    3
# DRAGON     3
# BUG        1
# GRASS      1
# GROUND     1
# FAIRY      1
# Name: Primary Type, dtype: int64

# %%
pokemon.sort_values('Defense', ascending = False)[:10]['Primary Type'].value_counts()
# Out:
# STEEL     4
# ROCK      2
# POISON    1
# BUG       1
# ICE       1
# WATER     1
# Name: Primary Type, dtype: int64

# %%
pokemon.sort_values('Speed', ascending = False)[:10]['Primary Type'].value_counts()
# Out:
# PSYCHIC     5
# ELECTRIC    2
# BUG         2
# ROCK        1
# Name: Primary Type, dtype: int64

# %%
pokemon.sort_values('Total', ascending = False)[:10]['Primary Type'].value_counts()
# Out:
# PSYCHIC     3
# POISON      1
# DRAGON      1
# WATER       1
# GROUND      1
# FIGHTING    1
# FAIRY       1
# NORMAL      1
# Name: Primary Type, dtype: int64

# %%
pokemon.sort_values('Sp.Attack', ascending = False)[:10]['Primary Type'].value_counts().plot(kind = 'bar', title = 'Top Ten Sp.Attack Type')
plt.xlabel('Pokemon Type')
plt.ylabel('Total Count')
# Out:
# Text(0, 0.5, 'Total Count')

# %%
pokemon.sort_values('Sp.Defense', ascending = False)[:10]['Primary Type'].value_counts().plot(kind = 'bar', title = 'Top Ten Sp.Defense Pokemon Type')
plt.xlabel('Pokemon Type')
plt.ylabel('Total Count')
# Out:
# Text(0, 0.5, 'Total Count')

# %%
pokemon.sort_values('HP', ascending = False)[:10]['Primary Type'].value_counts().plot(kind = 'bar', title = 'Top Ten HP Pokemon Type')
plt.xlabel('Pokemon Type')
plt.ylabel('Total Count')
# Out:
# Text(0, 0.5, 'Total Count')

# %%
pokemon.sort_values('Attack', ascending = False)[:10]['Primary Type'].value_counts().plot(kind = 'bar', title = 'Top Ten Attack Pokemon Type')
plt.xlabel('Pokemon Type')
plt.ylabel('Total Count')
# Out:
# Text(0, 0.5, 'Total Count')

# %%
pokemon.sort_values('Defense', ascending = False)[:10]['Primary Type'].value_counts().plot(kind = 'bar', title = 'Top Ten Defense Pokemon Type')
plt.xlabel('Pokemon Type')
plt.ylabel('Total Count')
# Out:
# Text(0, 0.5, 'Total Count')

# %%
pokemon.sort_values('Speed', ascending = False)[:10]['Primary Type'].value_counts().plot(kind = 'bar', title = 'Top Ten Speed Pokemon Type')
plt.xlabel('Pokemon Type')
plt.ylabel('Total Count')
# Out:
# Text(0, 0.5, 'Total Count')

# %%
pokemon.sort_values('Total', ascending = False)[:10]['Primary Type'].value_counts().plot(kind = 'bar', title = 'Top Ten Overall Status Pokemon Type')
plt.xlabel('Pokemon Type')
plt.ylabel('Total Count')
# Out:
# Text(0, 0.5, 'Total Count')

# %%
pokemon.sort_values('Sp.Attack', ascending = False)[:10].dropna(subset = ['Name2'])
# Out:
#          Name           Name2 Primary Type Secondary type  Attack  Defense  \
# 195    Mewtwo   Mega Mewtwo Y      PSYCHIC            NaN     150       70
# 467    Deoxys    Attack Forme      PSYCHIC            NaN     180       20
# 464  Rayquaza   Mega Rayquaza       DRAGON         FLYING     180      100
# 460    Kyogre   Primal Kyogre        WATER            NaN     150       90
# 84   Alakazam   Mega Alakazam      PSYCHIC            NaN      50       65
# 125    Gengar     Mega Gengar        GHOST         POISON      65       80
# 845     Hoopa   Hoopa Unbound      PSYCHIC           DARK     160       60
# 756    Kyurem    White Kyurem       DRAGON            ICE     120       90
# 936  Necrozma  Ultra Necrozma      PSYCHIC         DRAGON     167       97
#
#       HP  Sp.Attack  Sp.Defense  Speed  Total
# 195  106        194         120    140    780
# 467   50        180          20    150    600
# 464  105        180         100    115    780
# ...

# %%
pokemon.sort_values('Sp.Defense', ascending = False)[:10].dropna(subset = ['Name2'])
# Out:
#            Name          Name2 Primary Type Secondary type  Attack  Defense  \
# 1033  Eternatus      Eternamax       POISON         DRAGON     115      250
# 468      Deoxys  Defense Forme      PSYCHIC            NaN      70      160
# 460      Kyogre  Primal Kyogre        WATER            NaN     150       90
#
#        HP  Sp.Attack  Sp.Defense  Speed  Total
# 1033  255        125         250    130   1125
# 468    50         70         160     90    600
# 460   100        180         160     90    770

# %%
pokemon.sort_values('Attack', ascending = False)[:10].dropna(subset = ['Name2'])
# Out:
#            Name           Name2 Primary Type Secondary type  Attack  Defense  \
# 194      Mewtwo   Mega Mewtwo X      PSYCHIC       FIGHTING     190      100
# 264   Heracross  Mega Heracross          BUG       FIGHTING     185      115
# 462     Groudon  Primal Groudon       GROUND           FIRE     180      160
# 464    Rayquaza   Mega Rayquaza       DRAGON         FLYING     180      100
# 467      Deoxys    Attack Forme      PSYCHIC            NaN     180       20
# 532    Garchomp   Mega Garchomp       DRAGON         GROUND     170      115
# 755      Kyurem    Black Kyurem       DRAGON            ICE     170      100
# 1028     Zacian   Crowned Sword        FAIRY          STEEL     170      115
# 936    Necrozma  Ultra Necrozma      PSYCHIC         DRAGON     167       97
#
#        HP  Sp.Attack  Sp.Defense  Speed  Total
# 194   106        154         100    130    780
# 264    80         40         105     75    600
# 462   100        150          90     90    770
# ...

# %%
pokemon.sort_values('Defense', ascending = False)[:10].dropna(subset = ['Name2'])
# Out:
#            Name         Name2 Primary Type Secondary type  Attack  Defense  \
# 1033  Eternatus     Eternamax       POISON         DRAGON     115      250
# 256     Steelix  Mega Steelix        STEEL         GROUND     125      230
# 368      Aggron   Mega Aggron        STEEL            NaN     140      230
# 106     Slowbro  Mega Slowbro        WATER        PSYCHIC      75      180
#
#        HP  Sp.Attack  Sp.Defense  Speed  Total
# 1033  255        125         250    130   1125
# 256    75         55          95     30    610
# 368    70         60          80     50    630
# 106    95        130          80     30    590

# %%
pokemon.sort_values('Speed', ascending = False)[:10].dropna(subset = ['Name2'])
# Out:
#             Name            Name2 Primary Type Secondary type  Attack  \
# 469       Deoxys      Speed Forme      PSYCHIC            NaN      95
# 1044     Calyrex     Shadow Rider      PSYCHIC          GHOST      85
# 84      Alakazam    Mega Alakazam      PSYCHIC            NaN      50
# 466       Deoxys     Normal Forme      PSYCHIC            NaN     150
# 467       Deoxys     Attack Forme      PSYCHIC            NaN     180
# 182   Aerodactyl  Mega Aerodactyl         ROCK         FLYING     135
#
#       Defense   HP  Sp.Attack  Sp.Defense  Speed  Total
# 469        90   50         95          90    180    600
# 1044       80  100        165         100    150    680
# 84         65   55        175         105    150    600
# 466        50   50        150          50    150    600
# 467        20   50        180          20    150    600
# 182        85   80         70          95    150    615

# %%
pokemon.sort_values('Total', ascending = False)[:10].dropna(subset = ['Name2'])
# Out:
#            Name           Name2 Primary Type Secondary type  Attack  Defense  \
# 1033  Eternatus       Eternamax       POISON         DRAGON     115      250
# 464    Rayquaza   Mega Rayquaza       DRAGON         FLYING     180      100
# 195      Mewtwo   Mega Mewtwo Y      PSYCHIC            NaN     150       70
# 194      Mewtwo   Mega Mewtwo X      PSYCHIC       FIGHTING     190      100
# 460      Kyogre   Primal Kyogre        WATER            NaN     150       90
# 462     Groudon  Primal Groudon       GROUND           FIRE     180      160
# 936    Necrozma  Ultra Necrozma      PSYCHIC         DRAGON     167       97
# 1030  Zamazenta  Crowned Shield     FIGHTING          STEEL     130      145
# 1028     Zacian   Crowned Sword        FAIRY          STEEL     170      115
#
#        HP  Sp.Attack  Sp.Defense  Speed  Total
# 1033  255        125         250    130   1125
# 464   105        180         100    115    780
# 195   106        194         120    140    780
# ...

# %%
pokemon['Primary Type'].value_counts()
# Out:
# WATER       134
# NORMAL      115
# GRASS        91
# BUG          81
# PSYCHIC      79
# FIRE         65
# ELECTRIC     62
# ROCK         60
# DARK         46
# GHOST        42
# FIGHTING     42
# POISON       41
# GROUND       41
# DRAGON       41
# ICE          39
# STEEL        36
# FAIRY        22
# FLYING        8
# Name: Primary Type, dtype: int64
